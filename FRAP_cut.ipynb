# %%
import pandas as pd
from pathlib import Path

# %%
dir = "/mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT"
folder = Path(dir)

# %%
dfs = []  # list of DataFrames

for file in folder.glob("*.csv"):
    df = pd.read_csv(file)
    dfs.append(df)
    print(file, df.shape[0])

print(f"Loaded {len(dfs)} files.")
# Out:
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_003.csv 44
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_004.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_005.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_006.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_007.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_008.csv 44
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_009.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_010.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_011.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_012.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_013.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_014.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_015.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_016.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_017.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_018.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_019.csv 44
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_020.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_021.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_022.csv 45
# /mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/WT_023.csv 45
# Loaded 21 files.

# %%
# Fix timescale
for df in dfs:
    time = 0
    nframes = len(df)
    time_factors = [(37, 0.659), (float("inf"), 5)]

    for n in range(1, nframes + 1):
        for nframe, sec in time_factors:
            if n < nframe:
                time += sec
                df.loc[n-1, "Time"] = time
                break
            else:
                continue

# %%
N = 43
trimmed_dfs = {}
output_folder = "/mnt/c/users/Elena/Desktop/Data_processing/280226_U2OS_live_FRAP2/results_WT/trimmed"
for file in folder.glob("*.csv"):
    df = pd.read_csv(file)
    df_trimmed = df.iloc[:N].copy()
    trimmed_dfs[file.stem] = df_trimmed

    # save file
    df_trimmed.to_csv(output_folder +  f"/{file.stem}_trimmed.csv", index=False)
