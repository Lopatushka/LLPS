# %%
# Import necessary libraries
import pandas as pd
#import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt
#from scipy.stats import ttest_ind
#from scipy.stats import mannwhitneyu
#from sklearn.preprocessing import StandardScaler
#from sklearn.decomposition import PCA

# %%
def boxplot(df, colname):
    plt.figure(figsize=(4, 5))

    plt.boxplot(df[colname])

    plt.ylabel("Foci MFI")
    plt.title("Foci MFI")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Load data

# %%
data = [
        {'name': 'WT', 'path': "/mnt/c/users/helen/Desktop/Ayriscan/WT/foci_filtered/foci_aggregation.csv"}
]

labels = [df['name'] for df in data]
print(labels)
# Out:
# ['WT']

# %%
dfs = []
for item in data:
        p = item["path"]
        df = pd.read_csv(p)
        dfs.append(df)

N_files = len(dfs)
print(f"Loaded {N_files} dataframes.")
# Out:
# Loaded 1 dataframes.

# %%
df.head()
# Out:
#                                               filname  n_foci  sigma_nm_mean  \
# 0   c1_wt-01-airyscan_processing-29_roi_0838-1294_...     495     107.892615
# 1   c1_wt-02-airyscan_processing-30_roi_0659-0815_...     696     106.252500
# 2   c1_wt-03-airyscan_processing-31_roi_0176-0806_...     436     109.450549
# 3   c1_wt-03-airyscan_processing-31_roi_0430-0917_...     510     107.502232
# 4   c1_wt-03-airyscan_processing-31_roi_1576-0427_...     245     136.569377
# 5   c1_wt-04-airyscan_processing-32_roi_1067-0827_...     308     116.063650
# 6   c1_wt-04-airyscan_processing-32_roi_1220-0677_...     246     115.581485
# 7   c1_wt-05-airyscan_processing-33_roi_0435-1906_...     274     119.236995
# 8   c1_wt-05-airyscan_processing-33_roi_0555-0414_...     523     120.000449
# 9   c1_wt-05-airyscan_processing-33_roi_0835-1300_...     526     111.029540
# 10  c1_wt-05-airyscan_processing-33_roi_0890-0927_...     485     108.732963
# 11  c1_wt-05-airyscan_processing-33_roi_1708-1862_...      95     118.036165
# 12  c1_wt-06-airyscan_processing-34_roi_0495-1172_...     661     100.205583
# 13  c1_wt-06-airyscan_processing-34_roi_1257-1281_...     275     106.244885
# 14  c1_wt-06-airyscan_processing-34_roi_1541-1530_...     372     143.127551
# 15  c1_wt-06-airyscan_processing-34_roi_1786-0426_...     408     100.262392
# 16  c1_wt-07-airyscan_processing-35_roi_0750-0860_...     348     121.488203
# 17  c1_wt-07-airyscan_processing-35_roi_1521-1359_...     584     108.802852
# 18  c1_wt-07-airyscan_processing-35_roi_1696-0847_...     140     116.701676
# 19  c1_wt-08-airyscan_processing-36_roi_1093-0987_...     316     116.009618
# 20  c1_wt-08-airyscan_processing-36_roi_1155-1479_...     199     132.583287
# 21  c1_wt-09-airyscan_processing-37_roi_0638-1070_...     317     128.702154
# 22  c1_wt-09-airyscan_processing-37_roi_1159-1766_...     434     125.035202
# 23  c1_wt-09-airyscan_processing-37_roi_1661-0616_...      21     116.455830
# 24  c1_wt-10-airyscan_processing-38_roi_0327-0646_...     238     129.418889
# 25  c1_wt-10-airyscan_processing-38_roi_1313-1458_...     314     126.845921
# 26  c1_wt-10-airyscan_processing-38_roi_1706-1750_...     307     125.355203
# 27  c1_wt-11-airyscan_processing-39_roi_0477-0462_...     733     113.949753
# 28  c1_wt-11-airyscan_processing-39_roi_1817-0487_...     394     117.379119
# 29  c1_wt-12-airyscan_processing-40_roi_0918-0703_...     271     120.583171
# 30  c1_wt-12-airyscan_processing-40_roi_1115-1553_...     761     114.239045
#
#     sigma_nm_sd  foci_MFI_mean  foci_MFI_sd
# 0     24.893058     233.459974    78.860493
# 1     23.131330     265.706577    91.091427
# 2     23.880434     322.408707   105.812546
# 3     23.743792     294.564484    88.310858
# 4     42.847728    1921.123952  1197.159729
# 5     28.351412     387.696010   182.550316
# 6     25.510615     344.257956   113.642907
# 7     32.159776     340.963971   168.212292
# 8     30.169428     214.028158    80.220143
# 9     25.124233     246.105421    89.880929
# 10    24.549209     246.303263    88.544029
# 11    26.918315     144.725640    35.867313
# 12    18.495254     197.724433    54.868841
# 13    25.003674     301.706664   104.713794
# 14    40.949299    2632.820546  1565.129227
# 15    21.271586     221.707094    62.220178
# 16    33.490379     310.577931   118.779989
# 17    22.635826     184.733194    51.189902
# 18    26.773382     130.883589    23.541266
# 19    28.688404     243.991630    89.794218
# 20    34.178605     165.788702    54.199585
# 21    31.101072     173.459432    52.656890
# 22    32.195318     168.928623    57.958898
# 23    30.557345     110.939499    11.136642
# 24    32.258550     150.171791    43.475538
# 25    31.255686     149.730669    38.242794
# 26    32.823510     151.338708    40.632494
# 27    27.203932     202.785903    83.993924
# 28    31.784224     500.547063   310.271577
# 29    31.067654     671.230294   240.805523
# 30    27.571800     196.974875    71.096947

# %%
boxplot(df, colname = 'n_foci')
